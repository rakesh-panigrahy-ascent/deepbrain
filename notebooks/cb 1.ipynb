# %%
from bs4 import *
import requests
import os

# %%
import simple_image_download.simple_image_download as simp

# %%
dn = simp.simple_image_download()

# %%
dn.download('pathology lab test reports', 10000)
# Out:
# HTTPSConnectionPool(host='www.rmlonline.com', port=443): Max retries exceeded with url: /website_sections/images/pathrep01.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# HTTPSConnectionPool(host='www.rmlonline.com', port=443): Max retries exceeded with url: /website_sections/images/pathrep03.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# HTTPSConnectionPool(host='www.rmlonline.com', port=443): Max retries exceeded with url: /website_sections/images/pathrep02.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# ...

# %%
from urllib.request import urlopen

# %%
url = "http://olympus.realpython.org/profiles/aphrodite"

# %%
url = 'https://www.1mg.com/'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')
 
urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# /health-plans?showBN=true&healthPlansSource=home__bottom_nav
# /subscription-plan/myplan?showBN=true
# /labs?showBN=true&labsSource=home__bottom_nav
# /my-account?showBN=true
# /buy-medicines
# /labs
# /health-products
# /online-doctor-consultation
# /labs/tests?test_type=package&browse_by=health-categories&browse_by_id=full-body-check-up-62
# /labs/tests?test_type=package&browse_by=health-categories&browse_by_id=diabetes-44
# /labs/tests?test_type=package&browse_by=health-categories&browse_by_id=women-health-59
# /labs/tests?test_type=package&browse_by=health-categories&browse_by_id=men-health-64
# /labs/tests?test_type=test&browse_by=health-categories&browse_by_id=Thyroid-Tests-83
# /labs/tests?test_type=package&browse_by=health-categories&browse_by_id=senior-citizen-60
# /categories/fitness-supplements/vitamins-minerals-9
# /categories/fitness-supplements/vitamins-minerals/omega-fatty-acids-163
# /categories/featured/new-age-brands-2385
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("epfl-llm/meditron-70b")
model = AutoModelForCausalLM.from_pretrained("epfl-llm/meditron-70b")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_errors.py:259, in hf_raise_for_status(response, endpoint_name)
#     258 try:
# --> 259     response.raise_for_status()
#     260 except HTTPError as e:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/epfl-llm/meditron-70b/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...
